# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Capstone projects/Vehicle Recognizer
# Out:
# /content/drive/My Drive/Capstone projects/Vehicle Recognizer

# %%
version = 3.1
img_path = 'test_images'
model_path = f'models/vehicles-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x144>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Watercrafts',
#  TensorBase(17),
#  TensorBase([3.4260e-03, 7.9700e-09, 1.1486e-06, 4.6755e-07, 1.7758e-03,
#              2.4902e-07, 2.5591e-02, 2.3631e-04, 1.9401e-05, 1.0233e-06,
#              8.8410e-05, 1.7050e-05, 1.1736e-06, 2.7024e-06, 2.9468e-07,
#              2.6978e-05, 1.3487e-05, 9.6880e-01]))

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x171>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Specialty vehicles ',
#  TensorBase(14),
#  TensorBase([6.2259e-06, 7.1797e-08, 1.2770e-06, 2.9590e-05, 5.9274e-06,
#              1.1691e-03, 1.9029e-06, 8.9868e-07, 2.1858e-02, 5.8354e-07,
#              2.4988e-07, 1.1057e-05, 5.8114e-06, 6.7284e-02, 8.9255e-01,
#              1.6709e-06, 1.7075e-02, 1.4500e-07]))

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x149>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Trucks ',
#  TensorBase(16),
#  TensorBase([6.3380e-05, 6.6329e-03, 4.9050e-06, 1.0901e-04, 1.4400e-04,
#              6.8331e-04, 7.5916e-05, 2.6818e-03, 6.4017e-03, 4.0874e-05,
#              1.4770e-02, 7.2828e-05, 5.6970e-06, 2.1552e-04, 2.0550e-01,
#              4.3100e-03, 7.5778e-01, 5.1330e-04]))

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x171>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Buses',
#  TensorBase(5),
#  TensorBase([1.3277e-08, 8.0156e-09, 2.1213e-10, 3.5780e-09, 1.4959e-09,
#              9.9999e-01, 2.5224e-08, 6.7475e-12, 9.2190e-07, 1.3767e-10,
#              3.1886e-09, 1.1422e-07, 2.3377e-09, 5.5426e-09, 9.5414e-06,
#              2.1043e-09, 9.6255e-08, 4.1276e-11]))
